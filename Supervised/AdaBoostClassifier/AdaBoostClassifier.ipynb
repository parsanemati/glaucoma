# %%
# coding: utf-8

# In[90]:




# coding: utf-8

# In[86]:


# original lang
# http://scikit-learn.org/stable/modules/multiclass.html
# Support multilabel:
# http://scikit-learn.org/stable/supervised_learning.html

from sklearn.metrics import classification_report
from sklearn.datasets import make_classification
from sklearn.svm import LinearSVC
import time
start = time.time()
import random
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
import pandas as pd
from sklearn.model_selection import *
from math import sqrt
from sklearn.metrics import mean_squared_error

#whole clf
from sklearn import svm
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.datasets import make_classification
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
# clf3 = LogisticRegression()
# from sklearn.tree import DecisionTreeClassifier
# clf4 40 = LogisticRegressionCV(random_state=0)
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import *
from sklearn.tree import DecisionTreeClassifier
from sklearn import *
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import RidgeClassifierCV
from sklearn.svm import NuSVC
from sklearn.svm import SVC
from sklearn.neighbors.nearest_centroid import NearestCentroid
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import *
from sklearn.neighbors import *
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score 
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import *

from sklearn.linear_model import PassiveAggressiveClassifier


df = pd.read_csv("data1_label.csv")
df.shape
# Out:
# (524, 1054)

# %%
data_selection = df.iloc[:,29:1054].fillna(0)
data_selection.shape
# Out:
# (524, 1025)

# %%
data_selection.head()
# Out:
#      P01    P02    P03    P04    P05    P06    P07    P08    P09    P10  ...  \
# 0  36.20  36.33  36.46  36.58  36.71  36.85  36.98  37.11  37.25  37.38  ...
# 1  46.28  46.24  46.19  46.15  46.10  46.04  45.99  45.93  45.87  45.81  ...
# 2  82.48  82.57  82.65  82.74  82.82  82.89  82.97  83.05  83.13  83.20  ...
# 3  60.97  61.25  61.53  61.81  62.08  62.35  62.61  62.86  63.11  63.36  ...
# 4  56.31  56.26  56.21  56.17  56.14  56.12  56.10  56.09  56.10  56.11  ...
#
#    P1016  P1017  P1018  P1019  P1020  P1021  P1022  P1023  P1024  Real Label
# 0  35.04  35.17  35.30  35.43  35.56  35.69  35.82  35.94  36.07           0
# 1  46.48  46.48  46.48  46.47  46.45  46.42  46.39  46.36  46.32           0
# 2  81.52  81.66  81.78  81.90  82.01  82.11  82.21  82.30  82.39           0
# 3  58.29  58.59  58.89  59.19  59.49  59.79  60.09  60.38  60.68           0
# 4  57.01  56.92  56.83  56.75  56.66  56.59  56.51  56.44  56.37           0
#
# [5 rows x 1025 columns]

# %%
# Splitting the data into 300 training instances and 104 test instances
n = 157
all_Ids = np.arange(len(data_selection))

# random.shuffle(all_Ids)
test_Ids = all_Ids[0:n]
train_Ids = all_Ids[n:]
data_test = data_selection.loc[test_Ids, :]
data_train = data_selection.loc[train_Ids, :]
# print(data_train.shape) , print(data_test.shape)

X_train = data_train.iloc[:,0:1024]
Y_train = data_train['Real Label']

x_test = data_test.iloc[:,0:1024]


y_test = data_test['Real Label']
print("done")
# Out:
# done

# %%
"**********************************************************************************************************"

clf0= AdaBoostClassifier(n_estimators=100  ,random_state=0 ,learning_rate=0.05)

"************************************************************************************************************"
eclf1 = clf0.fit(X_train, Y_train)
predict = eclf1.predict(x_test)
accuracy_real = accuracy_score(predict , y_test)
print("Accuracy is" , accuracy_real)

print()
print("Learning Rate from Traning: " , eclf1.score(X_train, Y_train))

scores_accuracy_cv = cross_val_score(eclf1, X_train, Y_train, cv=5, scoring='accuracy')
scores_accuracy_cv_mean=scores_accuracy_cv.mean()
print()

print("scores accuracy is " , scores_accuracy_cv)
print()

print("Mean Scores accuracy is \n ======>>>>" , scores_accuracy_cv_mean)


print("Accuracy for first", n, " records : %.2f" % accuracy_score(y_test, predict ))
# y_test.shape, predict.shape


# In[110]:
print()

MSE = metrics.mean_squared_error(y_test, predict)
print('MSE :', MSE )


RMSE = sqrt(mean_squared_error(y_test, predict))
print('RMSE :', RMSE )


# In[111]:

confusion_matrix_result=confusion_matrix(y_test, predict)
print()

print("Cross Validation Classification Confusion Matrix: \n" ,confusion_matrix_result )
# 0.9378787878787879
# Out:
# Accuracy is 0.6242038216560509
#
# Learning Rate from Traning:  0.8038147138964578
#
# scores accuracy is  [0.62162162 0.63513514 0.56164384 0.5890411  0.73972603]
#
# Mean Scores accuracy is
#  ======>>>> 0.6294335431321733
# Accuracy for first 157  records : 0.62
#
# MSE : 0.37579617834394907
# RMSE : 0.6130221679058181
#
# Cross Validation Classification Confusion Matrix:
#  [[32 29]
#  [30 66]]
